# %%
# %pip install pillow opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pillow in C:\Users\user\AppData\Roaming\Python\Python312\site-packages (10.0.1)
# Requirement already satisfied: opencv-python in C:\Users\user\AppData\Roaming\Python\Python312\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in C:\Users\user\AppData\Roaming\Python\Python312\site-packages (from opencv-python) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in C:\Users\user\AppData\Roaming\Python\Python312\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in C:\Users\user\AppData\Roaming\Python\Python312\site-packages (from opencv-python) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in C:\Users\user\AppData\Roaming\Python\Python312\site-packages (26.1.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/pip/

# %%
from PIL import Image
import numpy as np

# %%
filepath = r"C:\Users\user\Desktop\ai-ml\images\images.jpg"

# %%
image = Image.open(filepath)
image.show()

# %%
img = np.array(image)
img.shape
# Out:
# (183, 275, 3)

# %%
import cv2
image = cv2.imread(filepath)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (183, 275, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(image)
plt.axis('off') # Hide axes
plt.show()

# %%
img=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off') 
plt.show()

# %%
img= cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()

# %%
img.shape
# Out:
# (183, 275)
